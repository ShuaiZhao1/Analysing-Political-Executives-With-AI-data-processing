# %% [markdown]
# # Analysing Political Executives with AI
#
# ## Using AutoGluon to processing the data

# %%
# Link for how to install autogluon on Windows system
# https://auto.gluon.ai/stable/index.html
# For other operation systems, please also check this link for latest news. 

# test automl model
# install autogluon
# !pip3 install -U pip
# !pip3 install -U setuptools wheel

# CPU version of pytorch has smaller footprint - see installation instructions in
# pytorch documentation - https://pytorch.org/get-started/locally/
# !pip3 install torch==1.10.1+cpu -f https://download.pytorch.org/whl/cpu/torch_stable.html

# !pip3 install autogluon
# Out:
# ^C
# Collecting mxnet<2.0.0
#   Using cached mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# Requirement already satisfied: numpy<1.17.0,>=1.8.2 in c:\users\my\miniconda3\envs\ds\lib\site-packages (from mxnet<2.0.0) (1.16.6)
# Collecting graphviz<0.9.0,>=0.8.1
#   Using cached graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests<2.19.0,>=2.18.4 in c:\users\my\miniconda3\envs\ds\lib\site-packages (from mxnet<2.0.0) (2.18.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\my\miniconda3\envs\ds\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (2021.10.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\my\miniconda3\envs\ds\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\my\miniconda3\envs\ds\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\my\miniconda3\envs\ds\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (1.22)
# Installing collected packages: graphviz, mxnet
# Successfully installed graphviz-0.8.4 mxnet-1.7.0.post2

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split #splitting the dataset
import numpy as np

# %%
# Reading the data file
train_data = TabularDataset('data_normgroup.csv')
# Out:
# Loaded data from: /Users/zhaoshuai/Desktop/DA/Data/Data-2016/data_normgroup.csv | Columns = 21 / 21 | Rows = 851 -> 851

# %%
type(train_data)
# Out:
# autogluon.core.dataset.TabularDataset

# %%
#change label into growth_rate
id, label = 'leader', 'growth_rate'

# %%
#change label into growth_rate group
id, label = 'leader', 'growth_rate_arggrp'

# %%
train_data.columns
# Out:
# Index(['ccode', 'leader', 'entry', 'exit', 'exitcode', 'prevtimesinoffice',
#        'posttenurefate', 'gender', 'yrborn', 'yrdied', 'numentry', 'numexit',
#        'yrbegin', 'yrend', 'age', 'tenure', 'pop_x', 'begin_gdppc', 'pop_y',
#        'fties_range', 'growth_rate_arggrp'],
#       dtype='object')

# %%
train_data.head()
# Out:
#    ccode     leader  entry  exit  exitcode  prevtimesinoffice  posttenurefate  \
# 0    0.0      Grant    0.0   0.0  0.307692                0.0        0.833333
# 1    0.0      Hayes    0.0   0.0  0.307692                0.0        0.833333
# 2    0.0     Arthur    0.0   0.0  0.307692                0.0        0.833333
# 3    0.0  Cleveland    0.0   0.0  0.307692                0.0        0.833333
# 4    0.0   Harrison    0.0   0.0  0.307692                0.0        0.833333
#
#    gender    yrborn    yrdied  ...  numexit   yrbegin     yrend       age  \
# 0     0.5  0.158228  0.058394  ...      0.0  0.071429  0.041958  0.447761
# 1     0.5  0.158228  0.116788  ...      0.0  0.123377  0.069930  0.567164
# 2     0.5  0.202532  0.065693  ...      0.0  0.149351  0.097902  0.522388
# 3     0.5  0.253165  0.226277  ...      0.0  0.175325  0.125874  0.462687
# 4     0.5  0.227848  0.175182  ...      0.0  0.201299  0.153846  0.582090
#
#      tenure     pop_x  begin_gdppc     pop_y  fties_range  growth_rate_arggrp
# 0  0.142921  0.038437     0.096155  0.039998          0.5                   1
# 1  0.061228  0.042037     0.099577  0.048091          0.5                   1
# 2  0.050101  0.046222     0.126387  0.052595          0.5                   1
# 3  0.061228  0.050407     0.128735  0.057829          0.5                   1
# 4  0.061228  0.054656     0.134928  0.063066          0.5                   1
#
# [5 rows x 21 columns]

# %%
train_data.describe()
# Out:
#             ccode       entry        exit    exitcode  prevtimesinoffice  \
# count  851.000000  851.000000  851.000000  851.000000         851.000000
# mean     0.368658    0.091657    0.148061    0.364368           0.011751
# std      0.278480    0.205371    0.238190    0.170195           0.086653
# min      0.000000    0.000000    0.000000    0.000000           0.000000
# 25%      0.144880    0.000000    0.000000    0.307692           0.000000
# 50%      0.253813    0.000000    0.000000    0.307692           0.000000
# 75%      0.592593    0.000000    0.200000    0.307692           0.000000
# max      1.000000    1.000000    1.000000    1.000000           1.000000
#
#        posttenurefate      gender      yrborn      yrdied    numentry  \
# count      851.000000  851.000000  851.000000  851.000000  851.000000
# mean         0.632785    0.502938    0.583640    0.617582    0.091657
# std          0.286278    0.038235    0.210160    0.252753    0.205371
# min          0.000000    0.500000    0.000000    0.000000    0.000000
# 25%          0.500000    0.500000    0.424051    0.419708    0.000000
# 50%          0.833333    0.500000    0.626582    0.671533    0.000000
# 75%          0.833333    0.500000    0.750000    0.824818    0.000000
# max          1.000000    1.000000    1.000000    1.000000    1.000000
#
#           numexit     yrbegin       yrend         age      tenure       pop_x  \
# count  851.000000  851.000000  851.000000  851.000000  851.000000  824.000000
# mean     0.207951    0.548835    0.539513    0.541873    0.094550    0.022426
# std      0.294624    0.211690    0.236996    0.155022    0.125550    0.064028
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.396104    0.356643    0.440299    0.024407    0.002374
# 50%      0.000000    0.597403    0.587413    0.537313    0.061228    0.005752
# 75%      0.366667    0.707792    0.727273    0.641791    0.102047    0.019587
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        begin_gdppc       pop_y  fties_range  growth_rate_arggrp
# count   851.000000  823.000000   851.000000          851.000000
# mean      0.110613    0.025456     0.556404            4.014101
# std       0.125379    0.069849     0.158272            2.006997
# min       0.000000    0.000000     0.500000            1.000000
# 25%       0.032128    0.002745     0.500000            2.000000
# 50%       0.069051    0.006458     0.500000            4.000000
# 75%       0.135529    0.022125     0.500000            6.000000
# max       1.000000    1.000000     1.000000            7.000000

# %%
#split train data and test data
df_train,df_test=train_test_split(train_data, test_size=0.33, random_state=1)
df_train.shape, df_test.shape
# Out:
# ((570, 21), (281, 21))

# %%
predictor = TabularPredictor(label=label).fit(
    df_train.drop(columns=[id, 'leader']))
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220410_080350/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20220410_080350/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    570
# Train Data Columns: 19
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	7 unique label values:  [1, 4, 3, 5, 6, 2, 7]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 7
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    342.5 MB
# 	Train Data (Original)  Memory Usage: 0.09 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 19 | ['ccode', 'entry', 'exit', 'exitcode', 'prevtimesinoffice', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 17 | ['ccode', 'entry', 'exit', 'exitcode', 'prevtimesinoffice', ...]
# 		('int', ['bool']) :  2 | ['gender', 'fties_range']
# 	0.1s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 456, Val Rows: 114
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.5614	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.5702	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.7456	 = Validation score   (accuracy)
# 	0.53s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	Warning: Exception caused LightGBMXT to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Fitting model: LightGBM ...
# 	Warning: Exception caused LightGBM to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Fitting model: RandomForestGini ...
# 	0.9649	 = Validation score   (accuracy)
# 	0.51s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.9298	 = Validation score   (accuracy)
# 	0.51s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost ...
# 	1.0	 = Validation score   (accuracy)
# 	0.62s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.8772	 = Validation score   (accuracy)
# 	0.51s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.8772	 = Validation score   (accuracy)
# 	0.52s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost ...
# 	Warning: Exception caused XGBoost to fail during training... Skipping this model.
# 		XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ["dlopen(/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)"]
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 962, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 934, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 118, in _fit
#     try_import_xgboost()
#   File "/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/autogluon/core/utils/try_import.py", line 83, in try_import_xgboost
#     import xgboost
#   File "/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/xgboost/__init__.py", line 9, in <module>
#     from .core import DMatrix, DeviceQuantileDMatrix, Booster
#   File "/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/xgboost/core.py", line 195, in <module>
#     _LIB = _load_lib()
#   File "/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/xgboost/core.py", line 186, in _load_lib
#     'Error message(s): {}\n'.format(os_error_list))
# xgboost.core.XGBoostError: XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ["dlopen(/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)"]
#
# Fitting model: NeuralNetMXNet ...
# 	0.7456	 = Validation score   (accuracy)
# 	14.24s	 = Training   runtime
# 	1.5s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	Warning: Exception caused LightGBMLarge to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/zhaoshuai/opt/anaconda3/envs/automl/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Fitting model: WeightedEnsemble_L2 ...
# 	1.0	 = Validation score   (accuracy)
# 	0.11s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 22.49s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20220410_080350/")

# %%
predictor.leaderboard(df_test.drop(columns=[id, 'leader']), silent=True)
# Out:
#                  model  score_test  score_val  pred_time_test  pred_time_val  \
# 0             CatBoost    0.960854   1.000000        0.007123       0.001509
# 1  WeightedEnsemble_L2    0.960854   1.000000        0.010578       0.002136
# 2     RandomForestGini    0.957295   0.964912        0.130173       0.107910
# 3     RandomForestEntr    0.953737   0.929825        0.132809       0.107749
# 4       ExtraTreesGini    0.854093   0.877193        0.146801       0.107583
# 5       ExtraTreesEntr    0.850534   0.877193        0.149571       0.108037
# 6       NeuralNetMXNet    0.718861   0.745614        2.044115       1.496301
# 7      NeuralNetFastAI    0.715302   0.745614        0.018299       0.011590
# 8       KNeighborsDist    0.562278   0.570175        0.112195       0.109851
# 9       KNeighborsUnif    0.544484   0.561404        0.109570       0.116935
#
#     fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   0.618660                 0.007123                0.001509
# 1   0.730619                 0.003455                0.000627
# 2   0.511686                 0.130173                0.107910
# 3   0.513531                 0.132809                0.107749
# 4   0.509798                 0.146801                0.107583
# 5   0.515325                 0.149571                0.108037
# 6  14.236033                 2.044115                1.496301
# 7   0.530608                 0.018299                0.011590
# 8   0.006217                 0.112195                0.109851
# 9   0.013755                 0.109570                0.116935
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.618660            1       True          6
# 1           0.111959            2       True         10
# 2           0.511686            1       True          4
# 3           0.513531            1       True          5
# 4           0.509798            1       True          7
# 5           0.515325            1       True          8
# 6          14.236033            1       True          9
# 7           0.530608            1       True          3
# 8           0.006217            1       True          2
# 9           0.013755            1       True          1

# %%
predictor.feature_importance(df_test, subsample_size=None)
# Out:
# Computing feature importance via permutation shuffling for 20 features using 281 rows with 3 shuffle sets...
# 	1.91s	= Expected runtime (0.64s per shuffle set)
# 	0.13s	= Actual runtime (Completed 3 of 3 shuffle sets)
#                    importance    stddev   p_value  n  p99_high   p99_low
# ccode                0.822064  0.033948  0.000284  3  1.016590  0.627538
# pop_y                0.010676  0.003559  0.017549  3  0.031068 -0.009716
# pop_x                0.004745  0.002055  0.028595  3  0.016518 -0.007028
# yrbegin              0.004745  0.002055  0.028595  3  0.016518 -0.007028
# numexit              0.003559  0.000000  0.500000  3  0.003559  0.003559
# begin_gdppc          0.002372  0.004109  0.211325  3  0.025919 -0.021174
# exitcode             0.001186  0.002055  0.211325  3  0.012959 -0.010587
# posttenurefate       0.001186  0.002055  0.211325  3  0.012959 -0.010587
# yrborn               0.001186  0.002055  0.211325  3  0.012959 -0.010587
# yrend                0.001186  0.002055  0.211325  3  0.012959 -0.010587
# age                  0.000000  0.000000  0.500000  3  0.000000  0.000000
# numentry             0.000000  0.000000  0.500000  3  0.000000  0.000000
# leader               0.000000  0.000000  0.500000  3  0.000000  0.000000
# gender               0.000000  0.000000  0.500000  3  0.000000  0.000000
# prevtimesinoffice    0.000000  0.000000  0.500000  3  0.000000  0.000000
# exit                 0.000000  0.000000  0.500000  3  0.000000  0.000000
# entry                0.000000  0.000000  0.500000  3  0.000000  0.000000
# fties_range          0.000000  0.000000  0.500000  3  0.000000  0.000000
# yrdied              -0.002372  0.002055  0.908248  3  0.009401 -0.014146
# tenure              -0.002372  0.002055  0.908248  3  0.009401 -0.014146

# %%
predictor.evaluate(df_test.drop(columns=[id, 'leader']))
# Out:
# Evaluation: accuracy on test data: 0.9608540925266904
# Evaluations on test data:
# {
#     "accuracy": 0.9608540925266904,
#     "balanced_accuracy": 0.9623606455730459,
#     "mcc": 0.9546682751837687
# }
# {'accuracy': 0.9608540925266904,
#  'balanced_accuracy': 0.9623606455730459,
#  'mcc': 0.9546682751837687}

# %%
#better model with GPU, data contain large amout of text, use multimodal to transform characteristics,
#multi-model fusion
#hyperparameters='multimodal',
#num_stack_levels=1, num_bag_folds=5

# %% [markdown]
# ## Group the data by Polity datasets IV category

# %%
#Group by the three types, and count the number of each group of the three
df1.groupby(['Polity datasets IV category']).count()

# %% [markdown]
# ### Draw a figure to see the difference between each group in Polity datasets

# %%
#Use seaborn package to visualize the difference between the three types
import seaborn as sns
ax= sns.histplot(df1['Polity datasets IV category'])

# %% [markdown]
# ### Group the data by countries

# %%
df1.groupby(['Country-id']).mean()

# %%
print(df1)

# %% [markdown]
# ## Deal with the dataset with the name df2(Countries vs gdppc)

# %% [markdown]
# ## Read the data about gdppc from excel with the name df2

# %%
#Import the data about countries with yearly Real GDP per capita in 2011$
df2 = pd.read_excel (r'D:/Zhao Shuai/phd/lingnan/literature/Data/mpd2020.xlsx', sheet_name='Full data')

# %% [markdown]
# ### Summary about df2

# %%
df2.dtypes

# %%
#See the overall head of df2
df2.head

# %%
#Shows the rows count and the types
df2.info()

# %%
df2.describe()

# %% [markdown]
# ### Choose the data after 1945

# %%
df2.drop( df2[ df2['year'] < 1945 ].index , inplace=True) 
print(df2)

# %% [markdown]
# ### Delete the NaN and  Null value and abnormal data

# %%
#Check all the data
#Delete the NaN and  Null value and abnormal data
df2.describe(include = 'all')

# %%
#let’s see what is the proportion of NaN values using a visualization library called seaborn.
#In this heatmap, you can see in yellow (depending on the cmap you are using, but with mine it’s yellow) the NaN values in each column.
sns.heatmap(df2.isnull(), cmap='viridis')

# %%
#We will just keep the rows with a value in the gdppc column
df2 = df2.dropna(subset=['gdppc'])
print(df2)

# %% [markdown]
# ### Check the data

# %%
print(df2)

# %%
#Check whether gdppc has abnormal numbers or not
df2.groupby(['gdppc']).mean()

# %%
#Check whether country has abnormal numbers or not
df2.groupby(['country']).mean()

# %% [markdown]
# ### Delete the 0 in gdppc

# %%
#Deleter the 0 in gdppc
#df2.loc[(df2!='0.0000').any(axis=1)]
df2= df2[df2['gdppc'] != 0]
print(df2)

# %%
#Check if I delete the gdppc with 0
df2.groupby('gdppc').mean()

# %% [markdown]
# ### Group by country

# %%
#Group by country, and save the dataframe with name df2_cty, gdppc is the average value in these years.
df2_cty = df2.groupby('country').mean()
print(df2_cty)

# %%
#Check the type for each column
df2_cty.dtypes

# %%
#Because I have more than 100 countries, so I choose the first 30 to check
df2_cty.head(30)

# %%
#Visualize the first 30 countries by gdppc
df2_cty.head(30).plot(kind='barh', y= 'gdppc')
#plt.savefig('medals.svg')

# %% [markdown]
# ### Draw a boxplot to show the gdppc for different countries

# %%
#Show the gdppc of each country

#plt.savefig('medals.svg')

# %%
#Data visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display
display.set_matplotlib_formats('svg')

# %% [markdown]
# ### Draw a line to show the changes of U.S. gdppc over time

# %%
# Choose a single country, for example, choose the subset of United States
df2_usa = df2[df2.country == 'United States']
print(df2_usa)

# %%
# The change in per capita GDP of a country over time
plt.figure(figsize=(10,5))
sns.relplot(x="year", y="gdppc", kind="line", data=df2_usa)

# %%
# Create figure and plot space, what's wrong?
fig, ax = plt.subplots(figsize=(10, 6))

# Add x-axis and y-axis
ax.plot(df2['year'],
        df2['gdppc'],
        df2['country'] == 'United States', 
        color='blue',)

# Set title and labels for axes
ax.set(xlabel="Year",
       ylabel="Real GDP per capita in 2011$",
       title="Gdppc in different year")

plt.show()

# %% [markdown]
# ### Choose the top 20 countries with more data in gdppc

# %%
df2['country'].value_counts()[0:20]

# %% [markdown]
# ### Compare the gdppc between China and United States

# %%
#Choose China and United States in country
compare=df2['country'].isin(['China','United States'])
#sns.displot(pd.DataFrame({'gdppc': df2[compare]['year'],'country': df2[compare]['country']}),x= 'gdppc', hue='country', kind='kde');

#sns.set(style='darkgrid',)
 
# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "year", y = "gdppc", data = df2[compare])
 
plt.title("Line", fontsize = 15)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("gdppc", fontsize = 15)
plt.show()

# %%
#Compare their gdppc for max, min, mean, etc
ax = sns.boxplot (x = 'country', y = 'gdppc', data = df2[compare], fliersize=0)
ax.set_ylim([0, 45000]);
