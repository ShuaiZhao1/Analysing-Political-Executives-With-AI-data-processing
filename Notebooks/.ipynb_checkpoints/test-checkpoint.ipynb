# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Alternative to set svg for newer versions
# %matplotlib inline


# # Showing all the details of results
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib qt

# %%
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)  # Display all column content
pd.set_option('display.width', None)  # Adjust display width automatically

# %%
# Read the original dta(Stata) data download from Archigos website.
# load the data
datafile = './../Data/WDI_CSV_2024_06_28/WDICountry.csv'
data = pd.read_csv(datafile)

# %%
# Read the original dta(Stata) data download from Archigos website.
# load the data
datafile = './../Data/WDI_CSV_2024_06_28/WDICSV.csv'
data = pd.read_csv(datafile)

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')

# %%
data['Indicator Name'].describe()
# Out:
# count                                                396872
# unique                                                 1492
# top       Access to clean fuels and technologies for coo...
# freq                                                    266
# Name: Indicator Name, dtype: object

# %%
data['Indicator Name'].value_counts()
# Out:
# Indicator Name
# Access to clean fuels and technologies for cooking (% of population)             266
# Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)    266
# Personal remittances, received (% of GDP)                                        266
# Personal remittances, paid (current US$)                                         266
# Persistence to last grade of primary, total (% of cohort)                        266
#                                                                                 ...
# General government final consumption expenditure (constant 2015 US$)             266
# General government final consumption expenditure (annual % growth)               266
# General government final consumption expenditure (% of GDP)                      266
# GDP: linked series (current LCU)                                                 266
# Young people (ages 15-24) newly infected with HIV                                266
# Name: count, Length: 1492, dtype: int64
