# %% [markdown]
# # 帮忙画一下世界地图
#
# - 各个国家GDP，GDPPC，POP三者的世界地图。
# - 制定的year为：2015
# ![example image](example.png)

# %%
import pandas as pd

# dataset
# 

data_mpd2023_GDP = pd.read_excel('./../Data/mpd2023_web.xlsx', 'Full data')
data_mpd2023_GDP.drop(columns = ['country'], inplace=True)
data_mpd2023_GDP['GDP'] = data_mpd2023_GDP['gdppc'] * data_mpd2023_GDP['pop']

data_mpd2023_GDP
# Out:
#        countrycode                     region  year        gdppc       pop  \
# 0              AFG  South and South East Asia     1          NaN       NaN
# 1              AFG  South and South East Asia   730          NaN       NaN
# 2              AFG  South and South East Asia  1000          NaN       NaN
# 3              AFG  South and South East Asia  1090          NaN       NaN
# 4              AFG  South and South East Asia  1150          NaN       NaN
# ...            ...                        ...   ...          ...       ...
# 131139         ZWE         Sub Saharan Africa  2018  1900.199191  14096.56
# 131140         ZWE         Sub Saharan Africa  2019  1753.024449  14344.59
# 131141         ZWE         Sub Saharan Africa  2020  1585.972804  14614.82
# 131142         ZWE         Sub Saharan Africa  2021  1687.253154  14900.01
# 131143         ZWE         Sub Saharan Africa  2022  1703.529373  15204.66
#
#                  GDP
# 0                NaN
# 1                NaN
# ...
